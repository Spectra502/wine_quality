# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from scipy.stats import spearmanr, kendalltau
import numpy as np

# %%
dataframe = pd.read_csv("./winequality-white.csv", sep=";")

# %%
dataframe[:-5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# ...             ...               ...          ...             ...        ...
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
#
# ...

# %%
correlation, p_value = spearmanr(dataframe)

# %%
correlation_matrix = np.reshape(correlation, (len(dataframe.columns), len(dataframe.columns)))

# %%
plt.scatter(dataframe['quality'], dataframe['alcohol'])

# Adding title and labels
plt.title('Scatter Plot of Quality vs Alcohol')
plt.xlabel('Quality')
plt.ylabel('Alcohol')

# Show the plot
plt.show()

# %%
plt.scatter(dataframe['quality'], dataframe['citric acid'])

# Adding title and labels
plt.title('Scatter Plot of Quality vs Citric Acid')
plt.xlabel('Quality')
plt.ylabel('Citric acid')

# Show the plot
plt.show()
